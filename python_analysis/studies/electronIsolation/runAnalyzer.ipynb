# %%
# %load_ext autoreload
# %autoreload 2
import uproot
import numpy as np
import matplotlib.pyplot as plt
import awkward as ak
import sys
sys.path.append("/uscms/home/sbrightt/nobackup/iDM/iDMe_analysis/CMSSW_10_6_26/src/iDMe/python_analysis/analysisTools/")
from analysisTools import Analyzer
from analysisTools import loadSchema
import analysisTools as tools
import analysisSubroutines as routines
import importlib
import coffea.util as util
import time
import json
import os

# %%
# cut and histogram configs -- make edits here
cut_file = "cutConfig.py"
hist_file = "histoConfig.py"

# %% [markdown]
# # Run over all samples

# %%
samp = "skimmed_signal_v2_2018_aEM"
samp_dir = "/uscms/home/sbrightt/nobackup/iDM/iDMe_analysis/CMSSW_10_6_26/src/iDMe/python_analysis/configs/sample_configs/"
test = Analyzer(f"{samp_dir}/{samp}.json",hist_file,cut_file)
t1 = time.time()
out = test.process(execr='futures')
t2 = time.time()
print((t2-t1)/60)
util.save(out,f"{samp}.coffea")
del out, test
# Out:
#      Processing 100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68/68 [ 0:02:06 < 0:00:00 | ?    chunk/s ]
# Merging (local) 100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68/68 [ 0:02:14 < 0:00:00 | 0.5 merges/s ]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 2.672176516056061

# %%
samp = "skimmed_bkg_2018_QCD_TuneCP5_PSWeights"
samp_dir = "/uscms/home/sbrightt/nobackup/iDM/iDMe_analysis/CMSSW_10_6_26/src/iDMe/python_analysis/configs/sample_configs/"
test = Analyzer(f"{samp_dir}/{samp}.json",hist_file,cut_file)
t1 = time.time()
out = test.process(execr='futures')
t2 = time.time()
print((t2-t1)/60)
util.save(out,f"{samp}.coffea")
del out, test
# Out:
#      Processing 100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44/44 [ 0:01:13 < 0:00:00 | 0.6  chunk/s ]
# Merging (local) 100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44/44 [ 0:01:13 < 0:00:00 | ?   merges/s ]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 1.6751237630844116

# %%
samp = "skimmed_bkg_2018_DY"
samp_dir = "/uscms/home/sbrightt/nobackup/iDM/iDMe_analysis/CMSSW_10_6_26/src/iDMe/python_analysis/configs/sample_configs/"
test = Analyzer(f"{samp_dir}/{samp}.json",hist_file,cut_file)
t1 = time.time()
out = test.process(execr='futures')
t2 = time.time()
print((t2-t1)/60)
util.save(out,f"{samp}.coffea")
del out, test
# Out:
#      Processing 100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23/23 [ 0:00:33 < 0:00:00 | 0.8  chunk/s ]
# Merging (local) 100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23/23 [ 0:00:34 < 0:00:00 | ?   merges/s ]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 0.8389000813166301

# %%
samp = "skimmed_bkg_2018_Diboson"
samp_dir = "/uscms/home/sbrightt/nobackup/iDM/iDMe_analysis/CMSSW_10_6_26/src/iDMe/python_analysis/configs/sample_configs/"
test = Analyzer(f"{samp_dir}/{samp}.json",hist_file,cut_file)
t1 = time.time()
out = test.process(execr='futures')
t2 = time.time()
print((t2-t1)/60)
util.save(out,f"{samp}.coffea")
del out, test
# Out:
#      Processing 100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [ 0:00:31 < 0:00:00 | 0.4  chunk/s ]
# Merging (local) 100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [ 0:00:31 < 0:00:00 | ?   merges/s ]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 0.7212556401888529

# %%
samp = "skimmed_bkg_2018_Top"
samp_dir = "/uscms/home/sbrightt/nobackup/iDM/iDMe_analysis/CMSSW_10_6_26/src/iDMe/python_analysis/configs/sample_configs/"
test = Analyzer(f"{samp_dir}/{samp}.json",hist_file,cut_file)
t1 = time.time()
out = test.process(execr='futures')
t2 = time.time()
print((t2-t1)/60)
util.save(out,f"{samp}.coffea")
del out, test
# Out:
#      Processing 100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97/97 [ 0:03:41 < 0:00:00 | 0.6  chunk/s ]
# Merging (local) 100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97/97 [ 0:03:41 < 0:00:00 | ?   merges/s ]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 4.162852732340495

# %%
samp = "skimmed_bkg_2018_Triboson"
samp_dir = "/uscms/home/sbrightt/nobackup/iDM/iDMe_analysis/CMSSW_10_6_26/src/iDMe/python_analysis/configs/sample_configs/"
test = Analyzer(f"{samp_dir}/{samp}.json",hist_file,cut_file)
t1 = time.time()
out = test.process(execr='futures')
t2 = time.time()
print((t2-t1)/60)
util.save(out,f"{samp}.coffea")
del out, test
# Out:
#      Processing 100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [ 0:00:10 < 0:00:00 | 0.7  chunk/s ]
# Merging (local) 100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [ 0:00:11 < 0:00:00 | ?   merges/s ]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 0.27397521734237673

# %%
samp = "skimmed_bkg_2018_WJets"
samp_dir = "/uscms/home/sbrightt/nobackup/iDM/iDMe_analysis/CMSSW_10_6_26/src/iDMe/python_analysis/configs/sample_configs/"
test = Analyzer(f"{samp_dir}/{samp}.json",hist_file,cut_file)
t1 = time.time()
out = test.process(execr='futures')
t2 = time.time()
print((t2-t1)/60)
util.save(out,f"{samp}.coffea")
del out, test
# Out:
#      Processing 100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42/42 [ 0:03:09 < 0:00:00 | 0.3  chunk/s ]
# Merging (local) 100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42/42 [ 0:03:10 < 0:00:00 | ?   merges/s ]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 3.471546943982442

# %%
samp = "skimmed_bkg_2018_ZJets"
samp_dir = "/uscms/home/sbrightt/nobackup/iDM/iDMe_analysis/CMSSW_10_6_26/src/iDMe/python_analysis/configs/sample_configs/"
test = Analyzer(f"{samp_dir}/{samp}.json",hist_file,cut_file)
t1 = time.time()
out = test.process(execr='futures')
t2 = time.time()
print((t2-t1)/60)
util.save(out,f"{samp}.coffea")
del out, test
# Out:
#      Processing 100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22/22 [ 0:03:21 < 0:00:00 | 0.1  chunk/s ]
# Merging (local) 100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22/22 [ 0:03:22 < 0:00:00 | ?   merges/s ]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 3.6321027159690855

# %%
from coffea.nanoevents import NanoEventsFactory, NanoAODSchema, BaseSchema
import coffea.hist as hist
import coffea
import uproot
import numpy as np
import awkward as ak
import matplotlib.pyplot as plt
from analysisTools import *
import json

# %%
an = Analyzer("sampleList.json","histoList.json","histoPlotConfig.json")
an.loadTables()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2952/2765338469.py in <module>
# ----> 1 an = Analyzer("sampleList.json","histoList.json","histoPlotConfig.json")
#       2 an.loadTables()
#
# /uscms_data/d3/sbrightt/iDM/iDMe_analysis/CMSSW_10_6_26/src/iDMeAnalysis/python_analysis/signalStudies_ntuplizer_Oct21/coffea/analysisTools.py in __init__(self, fileList, histoList, histoStyle)
#      25         self.totalEvents = 0
#      26
# ---> 27         with open(fileList) as f:
#      28             js = json.load(f)
#      29         for sample in js:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sampleList.json'

# %%
an.fillHistos()

# %%
test = an.histos["matched_ele_trackHits"].integrate("sample","Mchi-42p0_dMchi-4p0_ctau-100").integrate("match",r"Low $p_T$")
test = test.rebin("vxy",10)
test = test.integrate("numTrkHits").rebin("numStripHits",25)
#plt.figure(figsize=(10,8))
#hist.plotgrid(test,row="numStripHits",col="vxy")
test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3548/424441909.py in <module>
#       4 #plt.figure(figsize=(10,8))
#       5 #hist.plotgrid(test,row="numStripHits",col="vxy")
# ----> 6 tet
#
# NameError: name 'tet' is not defined

# %%
an.plotEfficiencies()
# Out:
# /uscms_data/d3/sbrightt/miniconda3/envs/coffea/lib/python3.8/site-packages/coffea/hist/plot.py:423: RuntimeWarning: invalid value encountered in true_divide
#   rsumw = sumw_num / sumw_denom
# /uscms_data/d3/sbrightt/miniconda3/envs/coffea/lib/python3.8/site-packages/coffea/hist/plot.py:423: RuntimeWarning: invalid value encountered in true_divide
#   rsumw = sumw_num / sumw_denom
# /uscms_data/d3/sbrightt/miniconda3/envs/coffea/lib/python3.8/site-packages/coffea/hist/plot.py:423: RuntimeWarning: invalid value encountered in true_divide
#   rsumw = sumw_num / sumw_denom
# /uscms_data/d3/sbrightt/miniconda3/envs/coffea/lib/python3.8/site-packages/coffea/hist/plot.py:423: RuntimeWarning: invalid value encountered in true_divide
#   rsumw = sumw_num / sumw_denom
# /uscms_data/d3/sbrightt/miniconda3/envs/coffea/lib/python3.8/site-packages/coffea/hist/plot.py:423: RuntimeWarning: invalid value encountered in true_divide
#   rsumw = sumw_num / sumw_denom
# ...

# %%
an.plotHistos()
# Out:
# /uscms_data/d3/sbrightt/miniconda3/envs/coffea/lib/python3.8/site-packages/coffea/hist/plot.py:333: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax.set_ylim(0, None)
# /uscms_data/d3/sbrightt/miniconda3/envs/coffea/lib/python3.8/site-packages/coffea/hist/plot.py:333: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax.set_ylim(0, None)
# /uscms_data/d3/sbrightt/miniconda3/envs/coffea/lib/python3.8/site-packages/coffea/hist/plot.py:333: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax.set_ylim(0, None)
# /uscms_data/d3/sbrightt/miniconda3/envs/coffea/lib/python3.8/site-packages/coffea/hist/plot.py:333: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax.set_ylim(0, None)
# ...

# %%
an.plotHistos(density=True)
# Out:
# /uscms_data/d3/sbrightt/miniconda3/envs/coffea/lib/python3.8/site-packages/coffea/hist/plot.py:333: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax.set_ylim(0, None)
# /uscms_data/d3/sbrightt/miniconda3/envs/coffea/lib/python3.8/site-packages/coffea/hist/plot.py:333: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax.set_ylim(0, None)
# /uscms_data/d3/sbrightt/miniconda3/envs/coffea/lib/python3.8/site-packages/coffea/hist/plot.py:333: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax.set_ylim(0, None)
# /uscms_data/d3/sbrightt/miniconda3/envs/coffea/lib/python3.8/site-packages/coffea/hist/plot.py:333: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax.set_ylim(0, None)
# ...
